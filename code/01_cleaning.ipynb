# %% [markdown]
# # Cleaning

# %%
import pandas as pd
import numpy as np
import re

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
ak = pd.read_csv('../datasets/data_raw/alaska_single_engine.csv', low_memory=False)

# %%
ak.dtypes
# Out:
# Unnamed: 0               int64
# NtsbNo                  object
# EventType               object
# Mkey                     int64
# EventDate               object
# City                    object
# State                   object
# Country                 object
# ReportNo                object
# N                       object
# HasSafetyRec              bool
# ReportType              object
# OriginalPublishDate     object
# HighestInjuryLevel      object
# FatalInjuryCount         int64
# SeriousInjuryCount       int64
# MinorInjuryCount         int64
# ProbableCause           object
# EventID                float64
# Latitude               float64
# Longitude              float64
# Make                    object
# Model                   object
# AirCraftCategory        object
# AirportID               object
# AirportName             object
# AmateurBuilt            object
# NumberOfEngines         object
# Scheduled               object
# PurposeOfFlight         object
# FAR                     object
# AirCraftDamage          object
# WeatherCondition        object
# Operator                object
# ReportStatus            object
# RepGenFlag                bool
# DocketUrl               object
# DocketPublishDate       object
# Unnamed: 37            float64
# dtype: object

# %%
ak.isna().sum()
# Out:
# Unnamed: 0                0
# NtsbNo                    0
# EventType                 0
# Mkey                      0
# EventDate                 0
# City                      0
# State                     0
# Country                   0
# ReportNo               5645
# N                         0
# HasSafetyRec              0
# ReportType               22
# OriginalPublishDate     885
# HighestInjuryLevel     4044
# FatalInjuryCount          0
# SeriousInjuryCount        0
# MinorInjuryCount          0
# ProbableCause          1452
# EventID                5659
# Latitude                  0
# Longitude                 0
# Make                      0
# Model                     1
# AirCraftCategory          0
# AirportID              3510
# AirportName            3196
# AmateurBuilt              0
# NumberOfEngines           0
# Scheduled              4342
# PurposeOfFlight         414
# FAR                       0
# AirCraftDamage           52
# WeatherCondition         20
# Operator               2842
# ReportStatus              0
# RepGenFlag                0
# DocketUrl              4283
# DocketPublishDate      4283
# Unnamed: 37            5659
# dtype: int64

# %%
ak.shape
# Out:
# (5659, 39)

# %% [markdown]
# ## Data Cleaning

# %%
ak_clean = ak

# %%
# drop unnecessary columns
ak_clean = ak_clean.drop(['Unnamed: 0', 'Unnamed: 37', 'DocketUrl', 'DocketPublishDate', 'State', 'OriginalPublishDate', 'NumberOfEngines', 'ReportNo', 'Country', 'EventID', 'ReportStatus', 'RepGenFlag'], axis=1)

# %%
def camel_to_snake(column_name):
    result = []
    i = 0

    while i < len(column_name):
        if column_name[i].isupper():
            if i > 0 and not column_name[i - 1].isupper():
                result.append('_')
            result.append(column_name[i].lower())
        else:
            result.append(column_name[i])
        i += 1

    return ''.join(result)

# %%
# camel to snake case feature names
ak_clean.columns = [camel_to_snake(column) for column in ak_clean.columns]

# %%
ak_clean.rename(columns={'air_craft_category': 'aircraft_category', 'air_craft_damage': 'aircraft_damage'}, inplace=True)

# %%
# select multi-aircraft_columns
comma_columns = ['n', 'make', 'model', 'aircraft_category', 'purpose_of_flight', 'far', 'aircraft_damage', 'operator', 'amateur_built']
mask = ak_clean[comma_columns].apply(lambda x: all(',' in val for val in x), axis=1)

# %%
mask.value_counts()
# Out:
# False    5590
# True       69
# Name: count, dtype: int64

# %%
# drop multi-aircraft rows
ak_clean = ak_clean[-mask]
ak_clean.reset_index(drop=True, inplace=True)

# %%
ak_clean.shape
# Out:
# (5590, 27)

# %%
# fill na

ak_clean = ak_clean.fillna({'highest_injury_level': 'None Reported', 'aircraft_damage': 'None Reported'})

# %%
ak_clean = ak_clean.fillna({'airport_id': 'No Airport', 'airport_name': 'No Airport'})

# %%
ak_clean = ak_clean.fillna({'weather_condition': 'Unknown',
                 'scheduled': 'Unknown',
                 'operator': 'Unknown',
                 'purpose_of_flight': 'Unknown',
                 'report_type': 'Unknown',
                 'probable_cause': 'Unknown',
                 'model': 'Unknown'})

# %%
# uppercase city
ak_clean['city'] = ak_clean.city.str.upper()

# %%
# combined near city with city values
ak_clean['city'] = [x.split('NEAR ')[1] if 'NEAR' in x else x for x in ak_clean['city']]

# %%
# combine unknown purpose_of_flight values
ak_clean['purpose_of_flight'] = ak_clean['purpose_of_flight'].replace('UNK', 'Unknown')

# %%
# remap booleans
ak_clean['amateur_built'] = ak_clean['amateur_built'].replace({'FALSE': 0, 'TRUE': 1})

# %%
ak_clean['has_safety_rec'] = ak_clean['has_safety_rec'].replace({'False': 0, 'True': 1}).astype(int)

# %%
# convert to datetime
ak_clean['event_date'] = pd.to_datetime(ak_clean['event_date'])

# %%
ak_clean.head()
# Out:
#       ntsb_no event_type    mkey                event_date  \
# 0  ANC23LA086        ACC  193153 2023-09-24 08:30:00+00:00
# 1  ANC23LA084        ACC  193128 2023-09-20 12:00:00+00:00
# 2  ANC23LA080        ACC  193097 2023-09-18 13:00:00+00:00
# 3  ANC23LA082        ACC  193105 2023-09-16 16:50:00+00:00
# 4  ANC23LA078        ACC  193088 2023-09-16 15:00:00+00:00
#
#                        city       n  has_safety_rec    report_type  \
# 0  TRIMBLE RIVER / SKWENTNA  N2586R               0  DirectorBrief
# 1                    BETHEL  N8192D               0  DirectorBrief
# 2                     HOMER  N7558H               0  DirectorBrief
# 3              BEAVER CREEK   N713C               0  DirectorBrief
# 4                    NENANA   N907W               0  DirectorBrief
#
#   highest_injury_level  fatal_injury_count  serious_injury_count  \
# 0        None Reported                   0                     0
# 1        None Reported                   0                     0
# 2        None Reported                   0                     0
# 3        None Reported                   0                     0
# 4        None Reported                   0                     0
#
#    minor_injury_count probable_cause   latitude  longitude             make  \
# 0                   0        Unknown  61.775160 -152.15263           CESSNA
# 1                   0        Unknown  60.805019 -161.78648            PIPER
# 2                   0        Unknown  59.646929 -151.49323           CESSNA
# 3                   0        Unknown  64.267579 -147.68704            HELIO
# 4                   0        Unknown  64.650753 -149.83639  RHODES STEVEN D
#
#        model aircraft_category  airport_id       airport_name  amateur_built  \
# 0       182K               AIR  No Airport      Trimble River              0
# 1  PA-18-150               AIR  No Airport         No Airport              0
# 2      A185F               AIR         5BL  HOMER-BELUGA LAKE              0
# 3      H-295               AIR  No Airport         No Airport              0
# 4     SR3500               AIR  No Airport         No Airport              1
#
#   scheduled purpose_of_flight  far aircraft_damage weather_condition  \
# 0   Unknown              PERS  091     Substantial           Unknown
# 1   Unknown              PERS  091     Substantial           Unknown
# 2   Unknown               BUS  091     Substantial               VMC
# 3      NSCH               BUS  135     Substantial           Unknown
# 4   Unknown              PERS  091     Substantial               VMC
#
#                  operator
# 0                 Unknown
# 1                 Unknown
# 2       Adventure Airways
# 3  WRIGHT AIR SERVICE INC
# 4                 Unknown

# %% [markdown]
# ## Feature Engineering

# %%
ak_clean['event_year'] = ak_clean['event_date'].dt.year

# %%
ak_clean['event_month'] = ak_clean['event_date'].dt.month

# %%
ak_clean['event_day'] = ak_clean['event_date'].dt.day

# %%
ak_clean['event_time'] = ak_clean['event_date'].dt.time

# %%
ak_clean = ak_clean.drop('event_date', axis=1)

# %%
# engineer hour
ak_clean['event_hour'] = [x.hour for x in ak_clean['event_time']]

# %%
def get_time_of_day(time):
    if 5 <= time < 12:
        return "Morning"
    elif 12 <= time < 17:  
        return "Afternoon"
    elif 17 <= time < 21:
        return "Evening"
    else:
        return "Night"

# %%
# engineer event_time_of_day
ak_clean['event_time_of_day'] = ak_clean['event_hour'].apply(get_time_of_day)

# %%
def get_am_pm(hour):
    if hour == 0 or hour < 12:
        return "AM"
    else:
        return "PM"

# %%
ak_clean['event_am_pm'] = ak_clean['event_hour'].apply(get_am_pm)

# %%
def get_season(month):
    if 3 <= month <= 5:
        return "Spring"
    elif 6 <= month <= 8:
        return "Summer"
    elif 9 <= month <= 11:
        return "Fall"
    else:
        return "Winter"

# %%
# engineer season
ak_clean['event_season'] = ak_clean['event_month'].apply(get_season)

# %%
# engineer injury bool
ak_clean['has_injury'] = ak_clean.highest_injury_level.apply(lambda x: 0 if x == 'None Reported' else 1)

# %%
# engineer fatal injury bool
ak_clean['has_fatal_injury'] = ak_clean.highest_injury_level.apply(lambda x: 1 if x == 'Fatal' else 0)

# %%
# engineer aircraft damage bool
ak_clean['has_aircraft_damage'] = ak_clean.aircraft_damage.apply(lambda x: 0 if x == 'None Reported' else 1)

# %%
# engineer event type bool
ak_clean['is_accident'] = ak_clean.event_type.apply(lambda x: 0 if x == 'INC' else 1)

# %%
# engineer near airport
ak_clean['occurred_near_airport'] = ak_clean.airport_id.apply(lambda x: 0 if x == 'No Airport' else 1)

# %%
ak_clean['make'] = ak_clean['make'].str.upper()

# %%
ak_clean['model'] = ak_clean['model'].str.upper()

# %%
# engineer make_model
ak_clean['make_model'] = ak_clean['make'] + ' ' + ak_clean['model']

# %%
# aircraft family patterns
aircraft_patterns = {
    'AERONCA 15AC SEDAN': r'AERONCA [A-Z]?15AC\b',
    'AERONCA 7AC CHAMPION': r'AERONCA 7AC',
    'BEECHCRAFT 1900': r'BEECH 1900',
    'BEECHCRAFT 36 BONANZA': r'BEECH A36|BEECH 36|BEECH T36|BEECH G36',
    'BELL 206': r'BELL 206[A-Z]?\b',
    'CHAMPION/ BELLANCA/ AMERICAN CHAMPION CITABRIA': r'7ECA\b|7GCAA\b|7GCB|7KCAB\b|8KCAB\b|CHAMPION 7EC|CHAMPION 7GC\b',
    'CHAMPION/ BELLANCA/ AMERICAN CHAMPION SCOUT': r'8GCBC\b',
    'CESSNA 140': r'CESSNA [A-Z]?[-\s]*140[A-Z]?\b',
    'CESSNA 150': r'CESSNA [A-Z]?[-\s]*150[A-Z]?\b',
    'CESSNA 152': r'CESSNA [A-Z]?[-\s]*152[A-Z]?\b',
    'CESSNA 170': r'CESSNA [A-Z]?[-\s]*170[A-Z]?\b',
    'CESSNA 175 SKYLARK': r'CESSNA [A-Z]?[-\s]*175[A-Z]?\b',
    'CESSNA 172 SKYHAWK': r'CESSNA [A-Z]?[-\s]*172[A-Z]?\b',
    'CESSNA 177 CARDINAL': r'CESSNA [A-Z]?[-\s]*177[A-Z]*?\b',
    'CESSNA 180 SKYWAGON': r'CESSNA [A-Z]?[-\s]*180[A-Z]?\b',
    'CESSNA 182 SKYLANE': r'CESSNA [A-Z]?[-\s]*182[A-Z]?\b',
    'CESSNA 185 SKYWAGON': r'CESSNA [A-Z]?[-\s]?185[A-Z]?\b',
    'CESSNA 206 STATIONAIR': r'CESSNA [A-Z]?[-\s]*206[A-Z]?\b|CESSNA TU206',
    'CESSNA 207': r'CESSNA [A-Z]?[-\s]*207[A-Z]?\b',
    'CESSNA 208 CARAVAN': r'CESSNA [A-Z]?[-\s]*208[A-Z]?\b',
    'CESSNA 210': r'CESSNA 210',
    'CESSNA 402': r'CESSNA [A-Z]?402[A-Z]?\b',
    'DE HAVILLAND DHC-2 BEAVER': r'DE[\s]*HAVILLAND DHC[-\s]*2\b|DE[\s]*HAVILLAND BEAVER DHC[-\s]*2',
    'DE HAVILLAND DHC-3 OTTER': r'DE[\s]*HAVILLAND DHC[-\s]*3\b|DE[\s]*HAVILLAND OTTER DHC[-\s]*3',
    'DE HAVILLAND DHC-6 TWIN OTTER': r'DE[\s]*HAVILLAND DHC[-\s]*6\b',
    'DOUGLAS DC-3': r'DOUGLAS DC[-\s]*3',
    'DOUGLAS DC-6': r'DOUGLAS DC[-\s]*6',
    'GRUMMAN G-44 WIDGEON': r'GRUMMAN G[-\s]*44',
    'HELIO COURIER': r'HELIO H',
    'LUSCOMBE 8': r'LUSCOMBE 8',
    'PIPER J-3 CUB': r'PIPER J[-\s]*3',
    'PIPER J-5 CUB CRUISER': r'PIPER J[-\s]*5',
    'PIPER PA-11 CUB SPECIAL': r'PIPER\s*PA[-\s]*11[-\s]*\d*[A-Z]?\b',
    'PIPER PA-12 SUPER CRUISER': r'PIPER\s*PA[-\s]*12[-\s]*\d*[A-Z]?\b',
    'PIPER PA-14 FAMILY CRUISER': r'PIPER\s*PA[-\s]*14[-\s]*\d*[A-Z]?\b',
    'PIPER PA-16 CLIPPER': r'PIPER\s*PA[-\s]*16[-\s]*\d*[A-Z]?\b',
    'PIPER PA-18 SUPER CUB': r'PIPER\s*PA[-\s]*18[-\s]*\d*[A-Z]?\b',
    'PIPER PA-20 PACER': r'PIPER\s*PA[-\s]*20[-\s]*\d*[A-Z]?\b',
    'PIPER PA-22 TRI-PACER': r'PIPER\s*PA[-\s]*22[-\s]*\d*[A-Z]?\b',
    'PIPER PA-28 CHEROKEE': r'PIPER\s*PA[-\s]*28[-\s]*\d*[A-Z]?\b',
    'PIPER PA-31 NAVAJO': r'PIPER\s*PA[-\s]*31[-\s]*\d*[A-Z]?\b',
    'PIPER PA-32 CHEROKEE SIX': r'PIPER\s*PA[-\s]*32[-\s]*\d*[A-Z]?\b',
    'STINSON 108': r'STINSON 108',
    'MAULE M-4': r'MAULE M[-\s]*4',
    'MAULE M-5': r'MAULE M[-\s]*5',
    'MAULE M-6': r'MAULE M[-\s]*6',
    'MAULE M-7': r'MAULE M[-\s]*7',
    'TAYLORCRAFT B': r'TAYLORCRAFT B',
    'TAYLORCRAFT F-19 SPORTSMAN': r'TAYLORCRAFT F[-\s]*19',
}

def group_models(make_model):
    grouped_models = []
    for aircraft, pattern in aircraft_patterns.items():
        if pattern and re.search(pattern, make_model):
            grouped_models.append(aircraft)

    if not grouped_models:
        return make_model
    elif len(grouped_models) == 1:
        return grouped_models[0]
    else:
        return make_model

# %%
# engineer aircraft families
ak_clean['aircraft_family'] = ak_clean['make_model'].apply(group_models)

# %%
ak_clean.model.nunique()
# Out:
# 1053

# %%
ak.Model.value_counts().head(25)
# Out:
# Model
# PA-18        439
# PA-18-150    245
# 180          226
# 185          185
# PA-12        172
# 207          135
# 170B         132
# DHC-2        127
# 172          112
# 206          106
# 7GCBC         78
# 207A          73
# PA-22         65
# A185F         65
# PA-32-300     60
# 185F          59
# 150           57
# PA-31-350     53
# 182           50
# PA18          49
# PA-20         48
# 8GCBC         44
# U206G         39
# 170           39
# DHC-3         36
# Name: count, dtype: int64

# %%
ak_clean.aircraft_family.nunique()
# Out:
# 758

# %%
# label uncommon families
aircraft_family_counts = ak_clean['aircraft_family'].value_counts()
uncommon_families = aircraft_family_counts[aircraft_family_counts < 10].index
ak_clean['aircraft_family'] = ak_clean['aircraft_family'].apply(lambda x: 'UNCOMMON FAMILY' if x in uncommon_families else x)

# %%
ak_clean.aircraft_family.nunique()
# Out:
# 50

# %%
ak_clean.aircraft_family.value_counts().head(50)
# Out:
# aircraft_family
# UNCOMMON FAMILY                                   961
# PIPER PA-18 SUPER CUB                             893
# CESSNA 185 SKYWAGON                               409
# CESSNA 180 SKYWAGON                               349
# CESSNA 206 STATIONAIR                             264
# CESSNA 207                                        228
# PIPER PA-12 SUPER CRUISER                         196
# CESSNA 170                                        193
# DE HAVILLAND DHC-2 BEAVER                         191
# CESSNA 172 SKYHAWK                                189
# PIPER PA-32 CHEROKEE SIX                          158
# CHAMPION/ BELLANCA/ AMERICAN CHAMPION CITABRIA    151
# PIPER PA-22 TRI-PACER                             136
# CESSNA 150                                        108
# CESSNA 182 SKYLANE                                100
# PIPER PA-31 NAVAJO                                 83
# STINSON 108                                        62
# PIPER PA-20 PACER                                  57
# BELL 206                                           54
# HELIO COURIER                                      54
# CESSNA 208 CARAVAN                                 53
# MAULE M-5                                          52
# PIPER PA-28 CHEROKEE                               51
# TAYLORCRAFT B                                      50
# CHAMPION/ BELLANCA/ AMERICAN CHAMPION SCOUT        44
# CESSNA 152                                         39
# DE HAVILLAND DHC-3 OTTER                           39
# CESSNA 140                                         36
# PIPER PA-14 FAMILY CRUISER                         33
# PIPER J-3 CUB                                      32
# MAULE M-4                                          32
# AERONCA 15AC SEDAN                                 25
# CESSNA 402                                         24
# HUGHES 369D                                        21
# PIPER PA-11 CUB SPECIAL                            21
# MAULE M-7                                          18
# TAYLORCRAFT F-19 SPORTSMAN                         17
# MAULE M-6                                          16
# PIPER J-5 CUB CRUISER                              15
# DE HAVILLAND DHC-6 TWIN OTTER                      14
# CESSNA 175 SKYLARK                                 14
# BEECHCRAFT 1900                                    13
# AERONCA 7AC CHAMPION                               13
# LUSCOMBE 8                                         13
# CESSNA 177 CARDINAL                                13
# GRUMMAN G-44 WIDGEON                               12
# ROBINSON HELICOPTER COMPANY R44 II                 12
# DOUGLAS DC-3                                       11
# PIPER PA-16 CLIPPER                                11
# DOUGLAS DC-6                                       10
# Name: count, dtype: int64

# %%
ak_clean.isna().sum()
# Out:
# ntsb_no                  0
# event_type               0
# mkey                     0
# city                     0
# n                        0
# has_safety_rec           0
# report_type              0
# highest_injury_level     0
# fatal_injury_count       0
# serious_injury_count     0
# minor_injury_count       0
# probable_cause           0
# latitude                 0
# longitude                0
# make                     0
# model                    0
# aircraft_category        0
# airport_id               0
# airport_name             0
# amateur_built            0
# scheduled                0
# purpose_of_flight        0
# far                      0
# aircraft_damage          0
# weather_condition        0
# operator                 0
# event_year               0
# event_month              0
# event_day                0
# event_time               0
# event_hour               0
# event_time_of_day        0
# event_am_pm              0
# event_season             0
# has_injury               0
# has_fatal_injury         0
# has_aircraft_damage      0
# is_accident              0
# occurred_near_airport    0
# make_model               0
# aircraft_family          0
# dtype: int64

# %%
ak_clean.dtypes
# Out:
# ntsb_no                   object
# event_type                object
# mkey                       int64
# city                      object
# n                         object
# has_safety_rec             int64
# report_type               object
# highest_injury_level      object
# fatal_injury_count         int64
# serious_injury_count       int64
# minor_injury_count         int64
# probable_cause            object
# latitude                 float64
# longitude                float64
# make                      object
# model                     object
# aircraft_category         object
# airport_id                object
# airport_name              object
# amateur_built              int64
# scheduled                 object
# purpose_of_flight         object
# far                       object
# aircraft_damage           object
# weather_condition         object
# operator                  object
# event_year                 int32
# event_month                int32
# event_day                  int32
# event_time                object
# event_hour                 int64
# event_time_of_day         object
# event_am_pm               object
# event_season              object
# has_injury                 int64
# has_fatal_injury           int64
# has_aircraft_damage        int64
# is_accident                int64
# occurred_near_airport      int64
# make_model                object
# aircraft_family           object
# dtype: object

# %%
ak_clean.head(60)
# Out:
#        ntsb_no event_type    mkey                      city       n  \
# 0   ANC23LA086        ACC  193153  TRIMBLE RIVER / SKWENTNA  N2586R
# 1   ANC23LA084        ACC  193128                    BETHEL  N8192D
# 2   ANC23LA080        ACC  193097                     HOMER  N7558H
# 3   ANC23LA082        ACC  193105              BEAVER CREEK   N713C
# 4   ANC23LA078        ACC  193088                    NENANA   N907W
# 31                 STINSON                108               AIR         NIN
# 32             DEHAVILLAND              DHC-2               AIR  No Airport
# 33                   MAULE           M-5-210C               AIR        NONE
# 34                   PIPER          PA-32-300               AIR  No Airport
# 35                   PIPER              PA-22               AIR  No Airport
# 36                   PIPER              PA-18               AIR  No Airport
# 37                   MAULE           M-4-210C               AIR  No Airport
# 38                  CESSNA                180               AIR         TKA
# 39  BUCK/CRAWFORD/CRAWFORD    CHRISTAVIA MK-1               AIR         LHD
# 40                  CESSNA                180               AIR  No Airport
# 41                   PIPER          PA-18-150               AIR  No Airport
# 42                   PIPER          PA-18-150               AIR         2Z5
# 43                   PIPER              PA-12               AIR  No Airport
# 44                   PIPER          PA-18-150               AIR         PAQ
# 45                   PIPER               PA31               AIR        37AA
# 46                   PIPER               PA22               AIR         ANC
# 47          DENNIS D DOWNS           CCK-1865               AIR  No Airport
# 48                   MAULE            M-7-235               AIR         SXQ
# 49     ROBINSON HELICOPTER             R44 II              HELI  No Airport
# 50             DEHAVILLAND  BEAVER DHC-2 MK.1               AIR         SXQ
# 51                   MAULE           M-5-235C               AIR        14AK
# 52                  CESSNA                170               AIR        PAWS
# 53                  CESSNA               182R               AIR         51Z
# 54                  CESSNA              A185F               AIR         HOM
# 55                 ENSTROM              F-28C              HELI         LHD
# 56                  CESSNA              U206F               AIR         BCV
# 57                   PIPER          PA-32-260               AIR         TKJ
# 58                   PIPER              PA-16               AIR         SXQ
# 59                  CESSNA                207               AIR        PAEW
#
#                       airport_name  amateur_built scheduled purpose_of_flight  \
# 0                    Trimble River              0   Unknown              PERS
# 1                       No Airport              0   Unknown              PERS
# 2                HOMER-BELUGA LAKE              0   Unknown               BUS
# 3                       No Airport              0      NSCH               BUS
# 4                       No Airport              1   Unknown              PERS
# 5                       No Airport              0   Unknown              PERS
# 6                       No Airport              0      NSCH           Unknown
# 7                       No Airport              0   Unknown              PERS
# 8                       No Airport              0   Unknown              POSI
# 9                       No Airport              0   Unknown              PERS
# 10                      No Airport              0   Unknown              PERS
# 11           Merle K Smith Airport              0   Unknown              PERS
# 12                         Peavine              0   Unknown              PERS
# 13                      No Airport              0      NSCH           Unknown
# 14                      No Airport              0   Unknown              PERS
# 15                      No Airport              0   Unknown              PERS
# 16                      No Airport              0   Unknown              PERS
# 17                      No Airport              0   Unknown              PERS
# 18                      No Airport              0   Unknown              PERS
# 19                      No Airport              0      NSCH               BUS
# 20                      No Airport              0   Unknown              PERS
# 21                      No Airport              0      NSCH               BUS
# 22                      No Airport              0   Unknown              PERS
# 23                      No Airport              0   Unknown              PERS
# 24  High Ridge Association Airport              1   Unknown              PERS
# 25                      No Airport              0   Unknown               BUS
# 26                      No Airport              0      NSCH               BUS
# 27                      No Airport              0   Unknown              PERS
# 28                      No Airport              0   Unknown              INST
# 29                      No Airport              0   Unknown              OWRK
# 30                      No Airport              0   Unknown              PERS
# 31                       NINILCHIK              0   Unknown              PERS
# 32                      No Airport              0      NSCH           Unknown
# 33       McArthur River Gravel Bar              0   Unknown              PERS
# 34                      No Airport              0      NSCH               BUS
# 35                      No Airport              0   Unknown              PERS
# 36                      No Airport              0   Unknown              PERS
# 37                      No Airport              0   Unknown              PERS
# 38               Talkeetna Airport              0   Unknown              PERS
# 39               Lake Hood Airport              0   Unknown              INST
# 40                      No Airport              0      NSCH               BUS
# 41                      No Airport              0   Unknown              PERS
# 42       Chena River Seaplane Base              0   Unknown              OWRK
# 43                      No Airport              0   Unknown              PERS
# 44                Palmer Municipal              0   Unknown              PERS
# 45          POINT THOMSON AIRSTRIP              0      NSCH               BUS
# 46      TED STEVENS ANCHORAGE INTL              0   Unknown              PERS
# 47                      No Airport              1   Unknown              PERS
# 48                Soldotna Airport              0   Unknown              PERS
# 49                      No Airport              0      NSCH               BUS
# 50                Soldotna Airport              0   Unknown              PERS
# 51                        Wick Air              0   Unknown              POSI
# 52                 Wasilla Airport              0   Unknown              INST
# 53               Al Wright Airport              0   Unknown              PERS
# 54                   Homer Airport              0   Unknown              PERS
# 55              Lake Hood Seaplane              0   Unknown              PERS
# 56               Birchwood Airport              0      NSCH               BUS
# 57                    Tok Junction              0   Unknown              PERS
# 58                Soldotna Airport              0   Unknown              PERS
# 59                          Newtok              0      NSCH               BUS
#
#     far aircraft_damage weather_condition                       operator  \
# 0   091     Substantial           Unknown                        Unknown
# 1   091     Substantial           Unknown                        Unknown
# 2   091     Substantial               VMC              Adventure Airways
# 3   135     Substantial           Unknown         WRIGHT AIR SERVICE INC
# 4   091     Substantial               VMC                        Unknown
# 5   091     Substantial           Unknown                        Unknown
# 6   135     Substantial               VMC             NEITZ AVIATION INC
# 7   091     Substantial           Unknown               GRIGGS JULIAN JL
# 8   091     Substantial           Unknown         WATTUM INVESTMENTS LLC
# 9   091     Substantial           Unknown                RIDER BRADLEY H
# 10  091     Substantial           Unknown                 KAGERER JOHN A
# 11  091     Substantial           Unknown                        Unknown
# 12  091     Substantial               VMC                        Unknown
# 13  135     Substantial               VMC             Alaska Skyways Inc
# 14  091       Destroyed               IMC                        Unknown
# 15  091     Substantial               VMC                        Unknown
# 16  091     Substantial               VMC                        Unknown
# 17  091     Substantial           Unknown                        Unknown
# 18  091     Substantial           Unknown                  RAY RICHARD L
# 19  135   None Reported               VMC          Rust's Flying Service
# 20  091   None Reported               VMC                        Unknown
# 21  135       Destroyed           Unknown     Willow Creek Aviation, LLC
# 22  091     Substantial               VMC                        Unknown
# 23  091     Substantial               VMC                        Unknown
# 24  091     Substantial               VMC                        Unknown
# 25  091     Substantial               VMC           SEAWIND AVIATION INC
# 26  135       Destroyed               VMC       MARITIME HELICOPTERS INC
# 27  091     Substantial           Unknown                        Unknown
# 28  091         Unknown               VMC                        Unknown
# 29  091     Substantial               VMC              Bristol Bay Lodge
# 30  091     Substantial               VMC                        Unknown
# 31  091     Substantial               VMC                        Unknown
# 32  135         Unknown           Unknown      WRANGELL MOUNTAIN AIR INC
# 33  091   None Reported               VMC                        Unknown
# 34  135     Substantial               VMC               Vertigo Air Taxi
# 35  091     Substantial               VMC                        Unknown
# 36  091     Substantial               VMC                        Unknown
# 37  091     Substantial               VMC                        Unknown
# 38  091   None Reported               VMC                        Unknown
# 39  091   None Reported               VMC                        Unknown
# 40  135     Substantial               VMC  Golden Eagle Outfitters, Inc.
# 41  091     Substantial               VMC                        Unknown
# 42  091     Substantial               VMC                        Unknown
# 43  091         Unknown               VMC                        Unknown
# 44  091     Substantial               VMC                        Unknown
# 45  135     Substantial               IMC                   JuniPogo LLC
# 46  091     Substantial               VMC                        Unknown
# 47  091     Substantial               VMC                        Unknown
# 48  091     Substantial               VMC                        Unknown
# 49  135     Substantial           Unknown          Willow Creek Aviation
# 50  091     Substantial               VMC                        Unknown
# 51  091     Substantial               VMC                        Unknown
# 52  091     Substantial               VMC                        Unknown
# 53  091     Substantial               VMC           CIVIL AIR PATROL INC
# 54  091     Substantial               VMC                        Unknown
# 55  091     Substantial               VMC                        Unknown
# 56  135     Substantial               VMC                        Unknown
# 57  091         Unknown               VMC                        Unknown
# 58  091     Substantial               VMC                        Unknown
# 59  135     Substantial               VMC              Yute Air Commuter
#
#     event_year  event_month  event_day event_time  event_hour  \
# 0         2023            9         24   08:30:00           8
# 1         2023            9         20   12:00:00          12
# 2         2023            9         18   13:00:00          13
# 3         2023            9         16   16:50:00          16
# 4         2023            9         16   15:00:00          15
# 5         2023            9         15   17:30:00          17
# 6         2023            9         12   19:47:00          19
# 7         2023            9         12   17:30:00          17
# 8         2023            9         12   13:15:00          13
# 9         2023            9         10   16:30:00          16
# 10        2023            9         10   13:30:00          13
# 11        2023            9          2   19:10:00          19
# 12        2023            8         30   13:00:00          13
# 13        2023            8         28   11:05:00          11
# 14        2023            8         27   09:00:00           9
# 15        2023            8         24   15:00:00          15
# 16        2023            8         22   11:00:00          11
# 17        2023            8         17   12:20:00          12
# 18        2023            8         15   13:00:00          13
# 19        2023            8         14   10:20:00          10
# 20        2023            8         10   12:10:00          12
# 21        2023            8          9   11:15:00          11
# 22        2023            8          4   17:43:00          17
# 23        2023            8          4   09:01:00           9
# 24        2023            8          1   14:15:00          14
# 25        2023            7         25   15:30:00          15
# 26        2023            7         20   10:05:00          10
# 27        2023            7         13   14:30:00          14
# 28        2023            7         13   14:00:00          14
# 29        2023            7         12   15:30:00          15
# 30        2023            7         12   15:20:00          15
# 31        2023            7         12   14:30:00          14
# 32        2023            7         11   19:00:00          19
# 33        2023            7          4   16:00:00          16
# 34        2023            7          2   14:10:00          14
# 35        2023            7          1   17:12:00          17
# 36        2023            7          1   11:40:00          11
# 37        2023            7          1   10:30:00          10
# 38        2023            6         19   11:00:00          11
# 39        2023            6         17   16:25:00          16
# 40        2023            6         16   10:35:00          10
# 41        2023            6          4   09:30:00           9
# 42        2023            5         29   07:30:00           7
# 43        2023            5         28   15:00:00          15
# 44        2023            5         19   16:02:00          16
# 45        2023            5         17   11:22:00          11
# 46        2023            5         17   09:55:00           9
# 47        2023            5         11   16:30:00          16
# 48        2023            5         10   12:10:00          12
# 49        2023            5          9   11:00:00          11
# 50        2023            4         22   11:45:00          11
# 51        2023            4          4   08:00:00           8
# 52        2023            4          2   15:20:00          15
# 53        2023            3         16   15:10:00          15
# 54        2023            3          6   17:00:00          17
# 55        2023            3          5   14:00:00          14
# 56        2023            2         13   15:00:00          15
# 57        2023            2         10   17:00:00          17
# 58        2023            2          8   17:00:00          17
# 59        2023            2          2   13:29:00          13
#
#    event_time_of_day event_am_pm event_season  has_injury  has_fatal_injury  \
# 0            Morning          AM         Fall           0                 0
# 1          Afternoon          PM         Fall           0                 0
# 2          Afternoon          PM         Fall           0                 0
# 3          Afternoon          PM         Fall           0                 0
# 4          Afternoon          PM         Fall           0                 0
# 5            Evening          PM         Fall           0                 0
# 6            Evening          PM         Fall           1                 1
# 7            Evening          PM         Fall           0                 0
# 8          Afternoon          PM         Fall           0                 0
# 9          Afternoon          PM         Fall           1                 0
# 10         Afternoon          PM         Fall           0                 0
# 11           Evening          PM         Fall           0                 0
# 12         Afternoon          PM       Summer           1                 0
# 13           Morning          AM       Summer           0                 0
# 14           Morning          AM       Summer           1                 1
# 15         Afternoon          PM       Summer           1                 0
# 16           Morning          AM       Summer           0                 0
# 17         Afternoon          PM       Summer           0                 0
# 18         Afternoon          PM       Summer           0                 0
# 19           Morning          AM       Summer           0                 0
# 20         Afternoon          PM       Summer           0                 0
# 21           Morning          AM       Summer           1                 1
# 22           Evening          PM       Summer           0                 0
# 23           Morning          AM       Summer           0                 0
# 24         Afternoon          PM       Summer           1                 0
# 25         Afternoon          PM       Summer           0                 0
# 26           Morning          AM       Summer           1                 1
# 27         Afternoon          PM       Summer           0                 0
# 28         Afternoon          PM       Summer           1                 0
# 29         Afternoon          PM       Summer           0                 0
# 30         Afternoon          PM       Summer           0                 0
# 31         Afternoon          PM       Summer           0                 0
# 32           Evening          PM       Summer           0                 0
# 33         Afternoon          PM       Summer           0                 0
# 34         Afternoon          PM       Summer           1                 1
# 35           Evening          PM       Summer           0                 0
# 36           Morning          AM       Summer           0                 0
# 37           Morning          AM       Summer           0                 0
# 38           Morning          AM       Summer           0                 0
# 39         Afternoon          PM       Summer           0                 0
# 40           Morning          AM       Summer           1                 1
# 41           Morning          AM       Summer           0                 0
# 42           Morning          AM       Spring           0                 0
# 43         Afternoon          PM       Spring           0                 0
# 44         Afternoon          PM       Spring           0                 0
# 45           Morning          AM       Spring           0                 0
# 46           Morning          AM       Spring           0                 0
# 47         Afternoon          PM       Spring           0                 0
# 48         Afternoon          PM       Spring           0                 0
# 49           Morning          AM       Spring           1                 0
# 50           Morning          AM       Spring           0                 0
# 51           Morning          AM       Spring           0                 0
# 52         Afternoon          PM       Spring           0                 0
# 53         Afternoon          PM       Spring           0                 0
# 54           Evening          PM       Spring           0                 0
# 55         Afternoon          PM       Spring           0                 0
# 56         Afternoon          PM       Winter           0                 0
# 57           Evening          PM       Winter           0                 0
# 58           Evening          PM       Winter           0                 0
# 59         Afternoon          PM       Winter           0                 0
#
#     has_aircraft_damage  is_accident  occurred_near_airport  \
# 0                     1            1                      0
# 48                           MAULE M-7-235
# 49              ROBINSON HELICOPTER R44 II
# 50           DEHAVILLAND BEAVER DHC-2 MK.1
# 51                          MAULE M-5-235C
# 52                              CESSNA 170
# 53                             CESSNA 182R
# 54                            CESSNA A185F
# 55                           ENSTROM F-28C
# 56                            CESSNA U206F
# 57                         PIPER PA-32-260
# 58                             PIPER PA-16
# 59                              CESSNA 207
#
#                                    aircraft_family
# 0                               CESSNA 182 SKYLANE
# 1                            PIPER PA-18 SUPER CUB
# 2                              CESSNA 185 SKYWAGON
# 3                                    HELIO COURIER
# 4                                  UNCOMMON FAMILY
# 5                            PIPER PA-18 SUPER CUB
# 6                            PIPER PA-18 SUPER CUB
# 7                                    TAYLORCRAFT B
# 8                              CESSNA 185 SKYWAGON
# 9                                  UNCOMMON FAMILY
# 10                             CESSNA 185 SKYWAGON
# 11     CHAMPION/ BELLANCA/ AMERICAN CHAMPION SCOUT
# 12                           PIPER PA-18 SUPER CUB
# 13                           CESSNA 206 STATIONAIR
# 14                                 UNCOMMON FAMILY
# 15                                 UNCOMMON FAMILY
# 16                           PIPER PA-18 SUPER CUB
# 17  CHAMPION/ BELLANCA/ AMERICAN CHAMPION CITABRIA
# 18                           PIPER PA-18 SUPER CUB
# 19                           CESSNA 206 STATIONAIR
# 20                             CESSNA 180 SKYWAGON
# 21                           PIPER PA-18 SUPER CUB
# 22                       PIPER PA-12 SUPER CRUISER
# 23                             CESSNA 185 SKYWAGON
# 24                                 UNCOMMON FAMILY
# 25                       DE HAVILLAND DHC-2 BEAVER
# 26                                        BELL 206
# 27                                 UNCOMMON FAMILY
# 28                           PIPER PA-18 SUPER CUB
# 29                       DE HAVILLAND DHC-2 BEAVER
# 30                                 UNCOMMON FAMILY
# 31                                     STINSON 108
# 32                       DE HAVILLAND DHC-2 BEAVER
# 33                                       MAULE M-5
# 34                        PIPER PA-32 CHEROKEE SIX
# 35                           PIPER PA-22 TRI-PACER
# 36                           PIPER PA-18 SUPER CUB
# 37                                       MAULE M-4
# 38                             CESSNA 180 SKYWAGON
# 39                                 UNCOMMON FAMILY
# 40                             CESSNA 180 SKYWAGON
# 41                           PIPER PA-18 SUPER CUB
# 42                           PIPER PA-18 SUPER CUB
# 43                       PIPER PA-12 SUPER CRUISER
# 44                           PIPER PA-18 SUPER CUB
# 45                              PIPER PA-31 NAVAJO
# 46                           PIPER PA-22 TRI-PACER
# 47                                 UNCOMMON FAMILY
# 48                                       MAULE M-7
# 49                                 UNCOMMON FAMILY
# 50                       DE HAVILLAND DHC-2 BEAVER
# 51                                       MAULE M-5
# 52                                      CESSNA 170
# 53                              CESSNA 182 SKYLANE
# 54                             CESSNA 185 SKYWAGON
# 55                                 UNCOMMON FAMILY
# 56                           CESSNA 206 STATIONAIR
# 57                        PIPER PA-32 CHEROKEE SIX
# 58                             PIPER PA-16 CLIPPER
# 59                                      CESSNA 207

# %% [markdown]
# ## Export

# %%
ak_clean.to_csv('../datasets/data_cleaned/alaska_single_engine_clean.csv', index=False)
