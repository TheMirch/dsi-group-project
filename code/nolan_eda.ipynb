# %%
import pandas as pd
import matplotlib.pyplot as plt

# pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_columns')

# %%
ak = pd.read_csv('../datasets/alaska_single_engine_clean.csv', low_memory=False)

# %%
ak.Model.value_counts()
# Out:
# Model
# PA-18             439
# PA-18-150         245
# 180               226
# 185               185
# PA-12             172
#                  ...
# Kitfox              1
# Sportsmen           1
# A-2 (Aircoupe)      1
# 406                 1
# DHC-2-MK3           1
# Name: count, Length: 1126, dtype: int64

# %%
model_counts = ak.Model.value_counts().head(30)

# %%
plt.figure(figsize=(12, 6))
model_counts.plot(kind='bar')
plt.title('Top 30 Aircraft Models vs. Number of Crashes')
plt.xlabel('Aircraft Model')
plt.ylabel('Number of Crashes')
plt.show()

# %%
ak.HighestInjuryLevel.value_counts()
# Out:
# HighestInjuryLevel
# No Injury Reported    4044
# Minor                  633
# Fatal                  599
# Serious                383
# Name: count, dtype: int64

# %%
injury_level_counts = ak.HighestInjuryLevel.value_counts()

# %%
plt.figure(figsize=(12, 6))
injury_level_counts.plot(kind='bar')
plt.title('Injury Level vs. Number of Crashes')
plt.xlabel('Injury Level')
plt.ylabel('Number of Crashes')
plt.show()

# %%
ak.AirCraftDamage.value_counts()
# Out:
# AirCraftDamage
# Substantial                4916
# Destroyed                   503
# Minor                       115
# No Damage Reported           52
# Substantial,Substantial      17
# Destroyed,Destroyed          10
# Minor,Substantial            10
# Substantial,Destroyed         6
# None,None                     6
# Destroyed,Substantial         5
# Substantial,Minor             5
# Unknown                       4
# Substantial,None              3
# Minor,Destroyed               2
# None,Substantial              2
# Substantial,Unknown           1
# Minor,Minor                   1
# Destroyed,None                1
# Name: count, dtype: int64

# %%
aircraft_damage_counts = ak.AirCraftDamage.value_counts().head(10)

# %%
plt.figure(figsize=(12, 6))
aircraft_damage_counts.plot(kind='bar')
plt.title('Top 10 Aircraft Damage vs. Number of Crashes')
plt.xlabel('Aircraft Damage')
plt.ylabel('Number of Crashes')
plt.show()

# %%
ak.Season.value_counts()
# Out:
# Season
# Summer    2346
# Fall      1428
# Spring    1249
# Winter     636
# Name: count, dtype: int64

# %%
aircraft_season_counts = ak.Season.value_counts().head(10)

# %%
plt.figure(figsize=(12, 6))
aircraft_season_counts.plot(kind='bar')
plt.title('Crashes by Season')
plt.xlabel('Season')
plt.ylabel('Number of Crashes')
plt.show()
